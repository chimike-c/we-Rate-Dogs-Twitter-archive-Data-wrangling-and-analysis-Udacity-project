# %% [markdown]
# # Project: Wrangling and Analyze Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
df_1 = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
import requests
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

with open("tweet_image_predictions.tsv", mode='wb') as file:
    file.write(response.content)

# %%
df_2 = pd.read_csv('tweet_image_predictions.tsv', sep='\t')

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# %%
consumer_key = 'Add Key'
consumer_secret = 'Add Secret'
access_token = 'Add token'
access_secret = 'Add Secret'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

#api = tweepy.API(auth)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
tweet_ids = df_1.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)


#id_of_tweet 

#tweet = api.get_status(id_of_tweet, tweet_mode='extended')
#print(tweet.text)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
df_twitterapi = pd.read_json('tweet_json.txt' , lines = True)

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %%
df_1
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
df_1.tweet_id.values
# Out:
# array([892420643555336193, 892177421306343426, 891815181378084864, ...,
#        666033412701032449, 666029285002620928, 666020888022790149])

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df_1.sample()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1968  673320132811366400                    NaN                  NaN
#
#                       timestamp  \
# 1968  2015-12-06 01:56:44 +0000
#
#                                                  source  \
# 1968  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1968  This is Frankie. He's wearing blush. 11/10 rea...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1968                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1968  https://twitter.com/dog_rates/status/673320132...                11
#
#       rating_denominator     name doggo floofer pupper puppo
# 1968                  10  Frankie  None    None   None  None

# %%
df_1.loc[df_1.in_reply_to_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 149   863079547188785154           6.671522e+17         4.196984e+09
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 184   856526610513747968           8.558181e+17         4.196984e+09
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# ...

# %%
df_1.loc[df_1.retweeted_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# 74    878316110768087041                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 91    874434818259525634                    NaN                  NaN
# 95    873697596434513921                    NaN                  NaN
# 97    873337748698140672                    NaN                  NaN
# 101   872668790621863937                    NaN                  NaN
# 109   871166179821445120                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# ...

# %%
df_1.loc[19]
# Out:
# tweet_id                                                     888202515573088257
# in_reply_to_status_id                                                       NaN
# in_reply_to_user_id                                                         NaN
# timestamp                                             2017-07-21 01:02:36 +0000
# source                        <a href="http://twitter.com/download/iphone" r...
# text                          RT @dog_rates: This is Canela. She attempted s...
# retweeted_status_id                                                 8.87474e+17
# retweeted_status_user_id                                            4.19698e+09
# retweeted_status_timestamp                            2017-07-19 00:47:34 +0000
# expanded_urls                 https://twitter.com/dog_rates/status/887473957...
# rating_numerator                                                             13
# rating_denominator                                                           10
# ...

# %%
df_1.loc[df_1.name == 'None']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 32    886054160059072513                    NaN                  NaN
# 35    885518971528720385                    NaN                  NaN
# 37    885167619883638784                    NaN                  NaN
# 41    884441805382717440                    NaN                  NaN
# 42    884247878851493888                    NaN                  NaN
# 47    883117836046086144                    NaN                  NaN
# 55    881633300179243008           8.816070e+17         4.738443e+07
# ...

# %%
df_1.loc[12].text
# Out:
# "Here's a puppo that seems to be on the fence about something haha no but seriously someone help her. 13/10 https://t.co/BxvuXk0UCm"

# %%
df_1.loc[59].text
# Out:
# "Ugh not again. We only rate dogs. Please don't send in well-dressed  floppy-tongued street penguins. Dogs only please. Thank you... 12/10 https://t.co/WiAMbTkDPf"

# %%
df_1.rating_numerator.sort_values()
# Out:
# 315        0
# 1016       0
# 2335       1
# 2261       1
# 2338       1
# 605        1
# 1446       1
# 1869       1
# 2091       1
# 2038       1
# 1940       1
# 1764       2
# 2310       2
# 1761       2
# 1920       2
# 2246       2
# 2237       2
# 2349       2
# 2326       2
# 2079       2
# 2305       3
# 1249       3
# 1898       3
# 1478       3
# 1692       3
# 2202       3
# 765        3
# 1928       3
# 1314       3
# 2183       3
#         ...
# 866       14
# 83        14
# 291       15
# 285       15
# 55        17
# 1663      20
# 516       24
# 1712      26
# 763       27
# 1433      44
# 1274      45
# 1202      50
# 1351      60
# 340       75
# 695       75
# 1254      80
# 433       84
# 1843      88
# 1228      99
# 1635     121
# 1634     143
# 1779     144
# 902      165
# 290      182
# 1120     204
# 2074     420
# 188      420
# 189      666
# 313      960
# 979     1776
# Name: rating_numerator, Length: 2356, dtype: int64

# %%
df_1.loc[df_1.rating_numerator <= 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 45    883482846933004288                    NaN                  NaN
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 165   860177593139703809                    NaN                  NaN
# 212   851861385021730816                    NaN                  NaN
# 229   848212111729840128                    NaN                  NaN
# 232   847962785489326080                    NaN                  NaN
# 274   840698636975636481           8.406983e+17         8.405479e+17
# 275   840696689258311684                    NaN                  NaN
# 281   839290600511926273                    NaN                  NaN
# 315   835152434251116546                    NaN                  NaN
# 323   834089966724603904                    NaN                  NaN
# 335   832645525019123713                    NaN                  NaN
# 368   828708714936930305                    NaN                  NaN
# ...

# %%
df_1.loc[df_1.rating_numerator <= 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 45    883482846933004288                    NaN                  NaN
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 165   860177593139703809                    NaN                  NaN
# 212   851861385021730816                    NaN                  NaN
# 229   848212111729840128                    NaN                  NaN
# 232   847962785489326080                    NaN                  NaN
# 274   840698636975636481           8.406983e+17         8.405479e+17
# 275   840696689258311684                    NaN                  NaN
# 281   839290600511926273                    NaN                  NaN
# 315   835152434251116546                    NaN                  NaN
# 323   834089966724603904                    NaN                  NaN
# 335   832645525019123713                    NaN                  NaN
# 368   828708714936930305                    NaN                  NaN
# ...

# %%
df_1.loc[45].text
# Out:
# 'This is Bella. She hopes her smile made you smile. If not, she is also offering you her favorite monkey. 13.5/10 https://t.co/qjrljjt948'

# %%
df_1.loc[229].text
# Out:
# "This is Jerry. He's doing a distinguished tongue slip. Slightly patronizing tbh. You think you're better than us, Jerry? 6/10 hold me back https://t.co/DkOBbwulw1"

# %%
df_1.loc[315].text
# Out:
# "When you're so blinded by your systematic plagiarism that you forget what day it is. 0/10 https://t.co/YbEJPkg4Ag"

# %%
df_1.loc[2326].text
# Out:
# "This is quite the dog. Gets really excited when not in water. Not very soft tho. Bad at fetch. Can't do tricks. 2/10 https://t.co/aMCTNWO94t"

# %%
df_1.loc[2335].text
# Out:
# 'This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv'

# %%
df_1.loc[2349].text
# Out:
# "This is an odd dog. Hard on the outside but loving on the inside. Petting still fun. Doesn't play catch well. 2/10 https://t.co/v5A4vzSDdc"

# %%
df_1.loc[2338].text
# Out:
# "Not familiar with this breed. No tail (weird). Only 2 legs. Doesn't bark. Surprisingly quick. Shits eggs. 1/10 https://t.co/Asgdc6kuLX"

# %%
df_1.loc[df_1.rating_denominator != 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# ...

# %%
df_1.loc[1433].text
# Out:
# "Happy Wednesday here's a bucket of pups. 44/40 would pet all at once https://t.co/HppvrYuamZ"

# %%
df_1.loc[1662].text
# Out:
# 'This is Darrel. He just robbed a 7/11 and is in a high speed police chase. Was just spotted by the helicopter 10/10 https://t.co/7EsP8LmSp5'

# %%
df_1.loc[1351].text
# Out:
# "Here is a whole flock of puppers.  60/50 I'll take the lot https://t.co/9dpcw6MdWa"

# %%
df_1.loc[1120].text
# Out:
# 'Say hello to this unbelievably well behaved squad of doggos. 204/170 would try to pet all at once https://t.co/yGQI3He3xv'

# %%
df_1.loc[1254].text
# Out:
# "Here's a brigade of puppers. All look very prepared for whatever happens next. 80/80 https://t.co/0eb7R1Om12"

# %%
df_1.loc[df_1.tweet_id.isnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
df_2
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
p1_false = df_2[df_2.p1_dog == False]

# %%
p1_false
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 22    666337882303524864    https://pbs.twimg.com/media/CT9OwFIWEAMuRje.jpg
# 25    666362758909284353    https://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# 29    666411507551481857    https://pbs.twimg.com/media/CT-RugiWIAELEaq.jpg
# 33    666430724426358785    https://pbs.twimg.com/media/CT-jNYqW4AAPi2M.jpg
# 43    666776908487630848    https://pbs.twimg.com/media/CUDeDoWUYAAD-EM.jpg
# 45    666786068205871104    https://pbs.twimg.com/media/CUDmZIkWcAAIPPe.jpg
# ...

# %%
p12_false = p1_false[p1_false.p2_dog == False]

# %%
p123_false = p12_false[p12_false.p3_dog == False]

# %%
p123_false
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 25    666362758909284353    https://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# 29    666411507551481857    https://pbs.twimg.com/media/CT-RugiWIAELEaq.jpg
# 45    666786068205871104    https://pbs.twimg.com/media/CUDmZIkWcAAIPPe.jpg
# 50    666837028449972224    https://pbs.twimg.com/media/CUEUva1WsAA2jPb.jpg
# 51    666983947667116034    https://pbs.twimg.com/media/CUGaXDhW4AY9JUH.jpg
# 53    667012601033924608    https://pbs.twimg.com/media/CUG0bC0U8AAw2su.jpg
# 56    667065535570550784    https://pbs.twimg.com/media/CUHkkJpXIAA2w3n.jpg
# ...

# %%
df_twitterapi
# Out:
#       contributors  coordinates          created_at display_text_range  \
# 0              NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1              NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2              NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3              NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4              NaN          NaN 2017-07-29 16:00:24           [0, 138]
# 5              NaN          NaN 2017-07-29 00:08:17           [0, 138]
# 6              NaN          NaN 2017-07-28 16:27:12           [0, 140]
# 7              NaN          NaN 2017-07-28 00:22:40           [0, 118]
# 8              NaN          NaN 2017-07-27 16:25:51           [0, 122]
# 9              NaN          NaN 2017-07-26 15:59:51           [0, 133]
# 10             NaN          NaN 2017-07-26 00:31:25           [0, 130]
# 11             NaN          NaN 2017-07-25 16:11:53           [0, 107]
# ...

# %%
df_twitterapi
# Out:
#       contributors  coordinates          created_at display_text_range  \
# 0              NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1              NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2              NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3              NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4              NaN          NaN 2017-07-29 16:00:24           [0, 138]
# 5              NaN          NaN 2017-07-29 00:08:17           [0, 138]
# 6              NaN          NaN 2017-07-28 16:27:12           [0, 140]
# 7              NaN          NaN 2017-07-28 00:22:40           [0, 118]
# 8              NaN          NaN 2017-07-27 16:25:51           [0, 122]
# 9              NaN          NaN 2017-07-26 15:59:51           [0, 133]
# 10             NaN          NaN 2017-07-26 00:31:25           [0, 130]
# 11             NaN          NaN 2017-07-25 16:11:53           [0, 107]
# ...

# %%
df_twitterapi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2326 entries, 0 to 2325
# Data columns (total 32 columns):
# contributors                     0 non-null float64
# coordinates                      0 non-null float64
# created_at                       2326 non-null datetime64[ns]
# display_text_range               2326 non-null object
# entities                         2326 non-null object
# extended_entities                2056 non-null object
# favorite_count                   2326 non-null int64
# favorited                        2326 non-null bool
# full_text                        2326 non-null object
# geo                              0 non-null float64
# id                               2326 non-null int64
# id_str                           2326 non-null int64
# in_reply_to_screen_name          77 non-null object
# in_reply_to_status_id            77 non-null float64
# in_reply_to_status_id_str        77 non-null float64
# ...

# %% [markdown]
# ### Quality issues
#
#
#
# 2. drop non-original tweets rows i.e. tweets that are retweets and/or are tweets in reply to dog-rating tweets
#
# 3. drop tweets (tweet id rows without dog names or wrong names ... "none" as dog name) ****
#
# 4. drop/correct rows with incorrect dog ratings numerator (index numbers- 2335,45, )
#
# 5. rows with incorrect dog rating denominators
#
# 5. correct timestamp data type (from object to timedate...)
#
# 6. drop rows without tweet ids... (NaN as value ...)
#
# 7. convert url(html file) to a df table
#
# 8. note rows in df_2 where p1_dog, p2_dog or p3_dog  is false i.e when the prediction is not an actual dog breed
#
# 9. image number column????
#
# 10. drop 'in_reply_to_status_id ' and 'in_reply_to_user_id' columns (they are not useful for our analysis)
#
# 11. drop 'retweeted_status_id' and 'retweeted_status_user_id' and 'retweeted_status_timestamp' column
#
# 12. drop 'source' column.... (not needed for our analysis)
#
# 13. convert tweet id column values in twitterapi data table from index form to plain values
#
# 14. non essential rows in twitterapi data df, leaving only tweet id, favorite count and retweet count columns
#
# 15. new tweet_id column should be created/extracted from extended_entities column (df_twitterapi_new) ... (Extract tweet IDs data from the extended_entities column in the df_twitterapi_new table, to form and replace the former column in the table. Using string extarct function...)

# %% [markdown]
# ### Tidiness issues
# 1. dog type should a column instaed of 4 different columns (doggo, floofer, puppo, pupper as variables...)
#
# 2. predicted dog breed (predicted_breed) should be a column instead of having columns p1, p1_dog, p1_conf, p2, p2_dog, p2_conf, p3, p3_dog and p3_conf. The predicted dog breed column is formed by indicating the prediction with the highest confidence (p1, p2, p3).
#
# 3. merge tables to form master dataset...

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data

df_1_clean = df_1.copy()
df_2_clean = df_2.copy()

df_twitterapi_clean = df_twitterapi.copy()

# %% [markdown]
# ### Issue #1:
# drop non-original tweets data rows i.e. tweets that are retweets and/or are tweets in reply to dog-rating tweets

# %% [markdown]
# #### Define:
#
# Drop/remove data rows in df_1(twitter archive data) for tweets/tweet IDs with retweeted_status_id and/or retweeted_status_timestamp... (text data for said column starts with 'RT'...)
#
# This is done using the below code block.
# The final output df_1_cleaning1a has the "cleaned" data.

# %% [markdown]
# #### Code

# %%
df_1_cleaning1 = df_1_clean[df_1_clean.retweeted_status_id.isnull()]

# %%
df_1_cleaning1a = df_1_cleaning1[df_1_clean.in_reply_to_status_id.isnull()]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Test

# %%
df_1_cleaning1a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2097 non-null int64
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     2097 non-null object
# source                        2097 non-null object
# text                          2097 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2094 non-null object
# rating_numerator              2097 non-null int64
# rating_denominator            2097 non-null int64
# name                          2097 non-null object
# doggo                         2097 non-null object
# floofer                       2097 non-null object
# pupper                        2097 non-null object
# puppo                         2097 non-null object
# ...

# %% [markdown]
# ### Issue #2:
#
#  'in_reply_to_status_id ' and 'in_reply_to_user_id' columns and 'retweeted_status_id' and 'retweeted_status_user_id' and 'retweeted_status_timestamp' columns  are not useful for our analysis

# %% [markdown]
# #### Define
#
# Drop the above listed columns in the df_1 table.

# %% [markdown]
# #### Code

# %%
df_1_cleaning2 = df_1_cleaning1a[['tweet_id','timestamp','source','text','expanded_urls','rating_numerator','rating_denominator','name','doggo','floofer','pupper','puppo']]

# %% [markdown]
# #### Test

# %%
df_1_cleaning2
# Out:
#                 tweet_id                  timestamp  \
# 0     892420643555336193  2017-08-01 16:23:56 +0000
# 1     892177421306343426  2017-08-01 00:17:27 +0000
# 2     891815181378084864  2017-07-31 00:18:03 +0000
# 3     891689557279858688  2017-07-30 15:58:51 +0000
# 4     891327558926688256  2017-07-29 16:00:24 +0000
# 5     891087950875897856  2017-07-29 00:08:17 +0000
# 6     890971913173991426  2017-07-28 16:27:12 +0000
# 7     890729181411237888  2017-07-28 00:22:40 +0000
# 8     890609185150312448  2017-07-27 16:25:51 +0000
# 9     890240255349198849  2017-07-26 15:59:51 +0000
# 10    890006608113172480  2017-07-26 00:31:25 +0000
# 11    889880896479866881  2017-07-25 16:11:53 +0000
# 12    889665388333682689  2017-07-25 01:55:32 +0000
# 13    889638837579907072  2017-07-25 00:10:02 +0000
# 14    889531135344209921  2017-07-24 17:02:04 +0000
# 15    889278841981685760  2017-07-24 00:19:32 +0000
# 16    888917238123831296  2017-07-23 00:22:39 +0000
# ...

# %%
list(df_1_cleaning2)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %% [markdown]
# ### Issue #3:
#
# rows with incorrect dog ratings (index number- 2335)

# %% [markdown]
# #### Define
#
# correct rating numerators/denominators for data rows with inaccurate dog ratings extracted from tweet text.
# correct numerator ratings and denominator ratings for index row 2335 (change numerator from 1 to 9)
# correct numerator ratings for index row 45 (chnage numerator from 5 to 13.5) , furthermore change datatype to float...

# %% [markdown]
# #### Code

# %%
df_1_cleaning2.loc[2335, "rating_numerator"] = 9
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_1_cleaning2.loc[2335, "rating_denominator"] = 10
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# #### Test

# %%
df_1_cleaning2.rating_numerator[2335]
# Out:
# 9

# %%
df_1_cleaning2.rating_denominator[2335]
# Out:
# 10

# %%
df_1_cleaning2.loc[2335]
# Out:
# tweet_id                                             666287406224695296
# timestamp                                     2015-11-16 16:11:11 +0000
# source                <a href="http://twitter.com/download/iphone" r...
# text                  This is an Albanian 3 1/2 legged  Episcopalian...
# expanded_urls         https://twitter.com/dog_rates/status/666287406...
# rating_numerator                                                      9
# rating_denominator                                                   10
# name                                                                 an
# doggo                                                              None
# floofer                                                            None
# pupper                                                             None
# puppo                                                              None
# Name: 2335, dtype: object

# %% [markdown]
# ### Issue #4:
#
# timestamp data type (from object to timedate...)

# %% [markdown]
# #### Define
#
# convert the datatype for the timestamp column...

# %% [markdown]
# #### Code

# %%
df_1_cleaning2.timestamp = pd.to_datetime(df_1_cleaning2.timestamp)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# #### Test

# %%
df_1_cleaning2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null datetime64[ns]
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# doggo                 2097 non-null object
# floofer               2097 non-null object
# pupper                2097 non-null object
# puppo                 2097 non-null object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 293.0+ KB

# %% [markdown]
# ### Issue #5:
#
# rows in df_2 where p1_dog, p2_dog or p3_dog  is false i.e when the prediction is not an actual dog breed

# %% [markdown]
# #### Define
#
# drop data rows where p1_dog, p2_dog or p3_dog = false.
# This is done by adding/concating the subset dataframe formed p123_false (df which contains data rows where p1_dog, p2_dog and p3_dog are false) to df_2 and dropping the duplicates...

# %% [markdown]
# #### Code

# %%
df_2_cleaning1 = pd.concat([df_2, p123_false]).drop_duplicates(keep=False)

# %%
df_2_cleaning1a = df_2_cleaning1.reset_index()

# %% [markdown]
# #### Test

# %%
df_2_cleaning1[(df_2_cleaning1.p1_dog == False) & (df_2_cleaning1.p2_dog == False) & (df_2_cleaning1.p3_dog == False)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %% [markdown]
# ### Issue #6:
# data rows without extended entities entries and reset the table index.

# %% [markdown]
# #### Define
# The next code block is used to drop data rows without extended entities entries and reset the table index.

# %% [markdown]
# #### Code

# %%
df_twitterapi_clean1 = df_twitterapi_clean[df_twitterapi_clean.extended_entities.notnull()].reset_index()

# %% [markdown]
# #### Test

# %%
print(df_twitterapi_clean1.extended_entities.isnull())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2026    False
# 2027    False
# 2028    False
# 2029    False
# 2030    False
# 2031    False
# 2032    False
# 2033    False
# 2034    False
# 2035    False
# 2036    False
# 2037    False
# 2038    False
# 2039    False
# 2040    False
# 2041    False
# 2042    False
# 2043    False
# 2044    False
# 2045    False
# 2046    False
# 2047    False
# 2048    False
# 2049    False
# 2050    False
# 2051    False
# 2052    False
# 2053    False
# 2054    False
# 2055    False
# ...

# %% [markdown]
# ### Issue #7:
# non essential rows in twitterapi data df, leaving only tweet id, favorite count and retweet count columns

# %% [markdown]
# #### Define
# drop non essential rows in twitterapi data df, leaving only tweet id, favorite count and retweet count columns

# %% [markdown]
# #### Code

# %%
df_twitterapi_clean2 = df_twitterapi_clean1[['id','favorite_count','retweet_count']]

# %% [markdown]
# #### Test

# %%
list(df_twitterapi_clean2)
# Out:
# ['id', 'favorite_count', 'retweet_count']

# %%
df_twitterapi_clean2.head()
# Out:
#                    id  favorite_count  retweet_count
# 0  892420643555336193           33595           6949
# 1  892177421306343426           29141           5252
# 2  891815181378084864           21930           3460
# 3  891689557279858688           36655           7159
# 4  891327558926688256           35046           7699

# %% [markdown]
# ### Issue #9:
# rows with incorrect dog ratings (index number 45)

# %% [markdown]
# #### Define
# correct numerator ratings for index row 45 (change numerator from 5 to 13.5)
#
# ...furthermore change datatype to float...

# %% [markdown]
# #### Code

# %%
df_1_cleaning2.loc[45, "rating_numerator"] = 13.5
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# #### Test

# %%
df_1_cleaning2.loc[45]
# Out:
# tweet_id                                             883482846933004288
# timestamp                                           2017-07-08 00:28:19
# source                <a href="http://twitter.com/download/iphone" r...
# text                  This is Bella. She hopes her smile made you sm...
# expanded_urls         https://twitter.com/dog_rates/status/883482846...
# rating_numerator                                                   13.5
# rating_denominator                                                   10
# name                                                              Bella
# doggo                                                              None
# floofer                                                            None
# pupper                                                             None
# puppo                                                              None
# Name: 45, dtype: object

# %% [markdown]
# ### Issue #10:
# source and expanaded urls columns in df_1

# %% [markdown]
# #### Define
# drop the source and 'expanded urls' columns from the df as they are not needed for our analysis

# %% [markdown]
# #### Code

# %%
df_1_cleaning2a = df_1_cleaning2[['tweet_id','timestamp','text','rating_numerator','rating_denominator','name','doggo','floofer','pupper','puppo']]

# %% [markdown]
# #### Test

# %%
df_1_cleaning2a.head()
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
# 1  This is Tilly. She's just checking pup on you....                13
# 2  This is Archie. He is a rare Norwegian Pouncin...                12
# 3  This is Darla. She commenced a snooze mid meal...                13
# 4  This is Franklin. He would like you to stop ca...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# ...

# %%
list(df_1_cleaning2a)

# %% [markdown]
# ### Tidiness Issues

# %% [markdown]
# ### Tidness Issue #1:
# dog type should a column instaed of 4 different columns (doggo, floofer, puppo, pupper as variables...)

# %% [markdown]
# #### Define
# drop the doggo, floofer, puppo, pupper columns and convert to a single column with doggo, floofer, puppo, pupper as variables.
#
# The final output dataframe, df_1_cleaning3a is that table after the "melting" the 4 columns to one 'dog_stage' column with doggo, floofer, puppo and pupper as variables, (and also without the 'value' column...)

# %% [markdown]
# #### Code

# %%
columns = ['doggo', 'pupper', 'puppo', 'floofer']
for column in columns:
    df_1_cleaning2a[column].replace('None', '', inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_1_cleaning3 = df_1_cleaning2a.assign(
                            dog_stage= df_1_cleaning2a.doggo + df_1_cleaning2a.pupper + df_1_cleaning2a.puppo + df_1_cleaning2a.floofer)

# %%
df_1_cleaning3.sample()
# Out:
#                 tweet_id           timestamp  \
# 1924  674075285688614912 2015-12-08 03:57:26
#
#                                                    text  rating_numerator  \
# 1924  Say hello to Mitch. He thinks that's a hat. No...              11.0
#
#       rating_denominator   name doggo floofer pupper puppo dog_stage
# 1924                  10  Mitch

# %%
df_1_cleaning3.dog_stage.replace('', np.nan, inplace=True)

# %%
df_1_cleaning3.drop(columns, axis=1, inplace=True)

# %%
df_1_cleaning3.sample()
# Out:
#                tweet_id           timestamp  \
# 897  759047813560868866 2016-07-29 15:27:55
#
#                                                   text  rating_numerator  \
# 897  This is Spencer. He's part of the Queen's Guar...              11.0
#
#      rating_denominator     name dog_stage
# 897                  10  Spencer       NaN

# %%
df_1_cleaning3.loc[df_1_cleaning3.dog_stage == 'doggopupper', 'dog_stage'] = 'doggo, pupper'
df_1_cleaning3.loc[df_1_cleaning3.dog_stage == 'doggopuppo', 'dog_stage'] = 'doggo, puppo'
df_1_cleaning3.loc[df_1_cleaning3.dog_stage == 'doggofloofer', 'dog_stage'] = 'doggo, floofer'

# %%
df_1_cleaning3.sample()
# Out:
#                tweet_id           timestamp  \
# 569  801958328846974976 2016-11-25 01:18:59
#
#                                                   text  rating_numerator  \
# 569  This is Ronnie. He hopes you're having a great...              12.0
#
#      rating_denominator    name dog_stage
# 569                  10  Ronnie       NaN

# %% [markdown]
# #### Test

# %%
df_1_cleaning3.sample()
# Out:
#               tweet_id           timestamp  \
# 44  883838122936631299 2017-07-09 00:00:04
#
#                                                  text  rating_numerator  \
# 44  This is Noah. He can't believe someone made th...                12
#
#     rating_denominator  name dog_stage
# 44                  10  Noah       NaN

# %%
df_1_cleaning3.sample()
# Out:
#                 tweet_id           timestamp  \
# 1898  674690135443775488 2015-12-09 20:40:38
#
#                                                    text  rating_numerator  \
# 1898  Meet Patrick. He's an exotic pup. Jumps great ...                 3
#
#       rating_denominator     name dog_stage
# 1898                  10  Patrick       NaN

# %%
df_1_cleaning3.head(10)
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
# 5  891087950875897856 2017-07-29 00:08:17
# 6  890971913173991426 2017-07-28 16:27:12
# 7  890729181411237888 2017-07-28 00:22:40
# 8  890609185150312448 2017-07-27 16:25:51
# 9  890240255349198849 2017-07-26 15:59:51
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
# 1  This is Tilly. She's just checking pup on you....                13
# 2  This is Archie. He is a rare Norwegian Pouncin...                12
# 3  This is Darla. She commenced a snooze mid meal...                13
# 4  This is Franklin. He would like you to stop ca...                12
# ...

# %%
df_1_cleaning3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 7 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null datetime64[ns]
# text                  2097 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# dog_stage             336 non-null object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 131.1+ KB

# %% [markdown]
# ### Tidness Issue #2:

# %% [markdown]
# #### Define
#
# create 'predicted breed' column from p1_conf, p2_conf and p3_conf columns (the one with the highest value...)
# value should be the value of coresponding value of p1 or p2 or p3... given that p1_dog or p2_dog or p3_dog is "True"
#
# p1_conf is always the highest value... given that p1_dog is true, predicted breed value should be the value of p1...
# if p1_dog is false, the predicted breed value should be the value of p2...

# %% [markdown]
# #### Code

# %%
length = len(df_2_cleaning1a)

# %%
length
# Out:
# 1751

# %%
for i in range(length):
    if df_2_cleaning1a.loc[i, 'p1_dog'] == True:
        df_2_cleaning1a.loc[i, 'predicted_breed'] = df_2_cleaning1a.loc[i, 'p1'] 
    elif df_2_cleaning1a.loc[i, 'p2_dog'] == True:
        df_2_cleaning1a.loc[i, 'predicted_breed'] = df_2_cleaning1a.loc[i, 'p2'] 
    else:
        df_2_cleaning1a.loc[i, 'predicted_breed'] = df_2_cleaning1a.loc[i, 'p3']

# %% [markdown]
# #### Test

# %%
df_2_cleaning1a.head()
# Out:
#    index            tweet_id                                          jpg_url  \
# 0      0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1      1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2      2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3      3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4      4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
# ...

# %%
df_2_cleaning1b = df_2_cleaning1a.copy()

# %% [markdown]
# ### Quality Issue #11:
# img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog columns in df_2 are not necessafry for our analysis... p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog columns have been used in to create a new column 'predicted breed'  which is more useful for our analysis...

# %% [markdown]
# #### Define
# drop the img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog columns in df_2

# %% [markdown]
# #### Code

# %%
df_2_cleaning2 = df_2_cleaning1b[['tweet_id', 'jpg_url', 'predicted_breed']]

# %% [markdown]
# #### Test

# %%
df_2_cleaning2.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#           predicted_breed
# 0  Welsh_springer_spaniel
# 1                 redbone
# 2         German_shepherd
# 3     Rhodesian_ridgeback
# 4      miniature_pinscher

# %% [markdown]
# ### Quality Issue #12:
# column name 'id' in df_twitterapi table

# %% [markdown]
# #### Define
# change the column name 'id' to 'tweet_id'
#
# This is done in order to ease up the dataset merging action to be performed later on in the project...

# %% [markdown]
# #### Code

# %%
df_twitterapi_clean2.rename(columns={'id':'tweet_id'}, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %% [markdown]
# #### Test

# %%
df_twitterapi_clean2.head()
# Out:
#              tweet_id  favorite_count  retweet_count
# 0  892420643555336193           33595           6949
# 1  892177421306343426           29141           5252
# 2  891815181378084864           21930           3460
# 3  891689557279858688           36655           7159
# 4  891327558926688256           35046           7699

# %%
df_twitterapi_clean2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2056 entries, 0 to 2055
# Data columns (total 3 columns):
# tweet_id          2056 non-null int64
# favorite_count    2056 non-null int64
# retweet_count     2056 non-null int64
# dtypes: int64(3)
# memory usage: 48.3 KB

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
df1_cleaned = df_1_cleaning3.copy()
df2_cleaned = df_2_cleaning2.copy()

dftwitterapi_cleaned = df_twitterapi_clean2.copy()

# %% [markdown]
# The output of cleaning process are stored in the following dataframes.
#
# df1_cleaned, df2_cleaned, dftwitterapi_cleaned
#
#
# For this project, these 3 datasets are combined to form a master dataset, saved as 'twitter_archive_master.csv'
#
# The below code block is used to merge the datasets to form master dataset.

# %%
dftwitterapi_cleaned.head()
# Out:
#              tweet_id  favorite_count  retweet_count
# 0  892420643555336193           33595           6949
# 1  892177421306343426           29141           5252
# 2  891815181378084864           21930           3460
# 3  891689557279858688           36655           7159
# 4  891327558926688256           35046           7699

# %%
dftwitterapi_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2056 entries, 0 to 2055
# Data columns (total 3 columns):
# tweet_id          2056 non-null int64
# favorite_count    2056 non-null int64
# retweet_count     2056 non-null int64
# dtypes: int64(3)
# memory usage: 48.3 KB

# %%
df1_dftwitterapi = pd.merge(df1_cleaned, dftwitterapi_cleaned,
                            on=['tweet_id'], how='left')

# %%
df1_dftwitterapi.head()
# Out:
#              tweet_id           timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56
# 1  892177421306343426 2017-08-01 00:17:27
# 2  891815181378084864 2017-07-31 00:18:03
# 3  891689557279858688 2017-07-30 15:58:51
# 4  891327558926688256 2017-07-29 16:00:24
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...              13.0
# 1  This is Tilly. She's just checking pup on you....              13.0
# 2  This is Archie. He is a rare Norwegian Pouncin...              12.0
# 3  This is Darla. She commenced a snooze mid meal...              13.0
# 4  This is Franklin. He would like you to stop ca...              12.0
#
#    rating_denominator      name dog_stage  favorite_count  retweet_count
# 0                  10   Phineas       NaN         33595.0         6949.0
# 1                  10     Tilly       NaN         29141.0         5252.0
# ...

# %%
df1_dftwitterapi.sample()
# Out:
#                 tweet_id           timestamp  \
# 1019  712438159032893441 2016-03-23 00:37:48
#
#                                                    text  rating_numerator  \
# 1019  This is Kane. He's a semi-submerged Haitian Hu...              11.0
#
#       rating_denominator  name dog_stage  favorite_count  retweet_count
# 1019                  10  Kane       NaN          4886.0         1407.0

# %%
df1_dftwitterapi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 9 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null datetime64[ns]
# text                  2097 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# dog_stage             336 non-null object
# favorite_count        1963 non-null float64
# retweet_count         1963 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 163.8+ KB

# %% [markdown]
# The df_1 and df_twitterapi datasets were merged to form df1_dftwitterapi dataset, containing tweet_id, tweet text, dog ratings, dog stage, favorite and retweet count, etc. This was done and tested with the above code blocks.
#
# This merged dataset should then be merged with the last dataframe df_2 containing the dogs predicted breed and the image url. The following code block helps us perform that action.

# %%
df2_df1_dftwitterapi = pd.merge(df2_cleaned, df1_dftwitterapi,
                            on=['tweet_id'], how='left')

# %%
df2_df1_dftwitterapi.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#           predicted_breed           timestamp  \
# 0  Welsh_springer_spaniel 2015-11-15 22:32:08
# 1                 redbone 2015-11-15 23:05:30
# 2         German_shepherd 2015-11-15 23:21:54
# 3     Rhodesian_ridgeback 2015-11-16 00:04:52
# 4      miniature_pinscher 2015-11-16 00:24:50
#
#                                                 text  rating_numerator  \
# 0  Here we have a Japanese Irish Setter. Lost eye...               8.0
# 1  This is a western brown Mitsubishi terrier. Up...               7.0
# ...

# %%
df2_df1_dftwitterapi.sample()
# Out:
#                 tweet_id                                          jpg_url  \
# 1396  813157409116065792  https://pbs.twimg.com/media/C0jqVVOXUAAGJ0G.jpg
#
#      predicted_breed           timestamp  \
# 1396        Pembroke 2016-12-25 23:00:08
#
#                                                    text  rating_numerator  \
# 1396  This is Layla. It is her first Christmas. She ...              12.0
#
#       rating_denominator   name dog_stage  favorite_count  retweet_count
# 1396                10.0  Layla       NaN          7328.0         2055.0

# %% [markdown]
# The resulting dataset formed from all 3 datasets merged together is then saved as "twitter_archive_master.csv".

# %%
twitter_archive_master = df2_df1_dftwitterapi.copy()

# %%
twitter_archive_master.to_csv("twitter_archive_master.csv")

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %% [markdown]
# The master dataset is then analyzed to draw various insights...

# %%
twitter_archive_master.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#           predicted_breed           timestamp  \
# 0  Welsh_springer_spaniel 2015-11-15 22:32:08
# 1                 redbone 2015-11-15 23:05:30
# 2         German_shepherd 2015-11-15 23:21:54
# 3     Rhodesian_ridgeback 2015-11-16 00:04:52
# 4      miniature_pinscher 2015-11-16 00:24:50
#
#                                                 text  rating_numerator  \
# 0  Here we have a Japanese Irish Setter. Lost eye...               8.0
# 1  This is a western brown Mitsubishi terrier. Up...               7.0
# ...

# %% [markdown]
# ### Insights:
# 1. Average dog ratings, confirming that users enjoy the content... (highest and lowest ratings)
#
# 2. Tweet interactions (retweets, favourites) for various predicted breeds
#
# 3. Diversity of the breeds recognizable by the 'model' used...
#
# 4. how users feel about common dog breeds compared to rare breeds...
#
# 5. Average dog ratings for each breed... (most likeable dog breed)

# %% [markdown]
# ### Insight 1:
# Average dog ratings, confirming that users enjoy the content... (highest and lowest ratings)

# %%
twitter_archive_master.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator  favorite_count  \
# count  1.751000e+03       1666.000000         1666.000000     1658.000000
# mean   7.415895e+17         11.398259           10.473589     7992.293727
# std    6.815223e+16          7.483516            6.340552    11761.907254
# min    6.660209e+17          0.000000            7.000000       66.000000
# 25%    6.783065e+17         10.000000           10.000000     1797.000000
# 50%    7.182469e+17         11.000000           10.000000     3709.000000
# 75%    7.966223e+17         12.000000           10.000000     9874.000000
# max    8.921774e+17        165.000000          150.000000   143706.000000
#
#        retweet_count
# count    1658.000000
# mean     2279.578408
# std      4144.509652
# min        11.000000
# 25%       513.250000
# 50%      1125.500000
# 75%      2578.750000
# max     70067.000000

# %% [markdown]
# The result of the above code block shows that over 75% of the dog ratings are at least 12/10 showing that content owners generally rate their dogs highly.
#
# The result also shows there is an aveage dog rating of approximately 11.4, also emphasizing that content owners generally rate their dogs highly (given the ratings are above 10/10).

# %% [markdown]
# ### Insight 2:
# Tweet interactions (retweets, favourites) for various predicted breeds

# %%
interactions_per_breed = twitter_archive_master.groupby("predicted_breed")['retweet_count', 'favorite_count']

# %%
retweet_interactions_per_breed = interactions_per_breed.sum()['retweet_count'].sort_values(ascending=False).reset_index(name="retweet_count")

# %%
retweet_interactions_per_breed.head()
# Out:
#       predicted_breed  retweet_count
# 0    golden_retriever       472843.0
# 1  Labrador_retriever       309225.0
# 2            Pembroke       234837.0
# 3           Chihuahua       208297.0
# 4             Samoyed       154848.0

# %%
favorite_interactions_per_breed = interactions_per_breed.sum()['favorite_count'].sort_values(ascending=False).reset_index(name="favorite_count")

# %%
favorite_interactions_per_breed.head()
# Out:
#       predicted_breed  favorite_count
# 0    golden_retriever       1673861.0
# 1  Labrador_retriever       1023837.0
# 2            Pembroke        899161.0
# 3           Chihuahua        662060.0
# 4      French_bulldog        522636.0

# %% [markdown]
# The results of the above code blocks show the dog breeds that had the highest user interactions (retweets and favorites). The results show that users interacted most with tweets about golden retrievers, Labrador retrievers, Pembroke and Chihuahuas.

# %% [markdown]
# ### Insights 3:
# Diversity of the breeds recognizable by the AI model used

# %%
breed_count = twitter_archive_master.groupby("predicted_breed").size()

# %%
breed_count = breed_count.sort_values(ascending=False).reset_index(name="Count")

# %%
breed_count.head()
# Out:
#       predicted_breed  Count
# 0    golden_retriever    173
# 1  Labrador_retriever    113
# 2            Pembroke     96
# 3           Chihuahua     95
# 4                 pug     65

# %% [markdown]
# The results of the above code blocks show that the AI model used to predict the dog breeds from the tweeted photos had a vast range and was able to detect up to 113 different dog breeds. The most common of the dog breeds were Golden retrievers, Labrador retrievers, Pembrokes, Chihuahua and Pugs.

# %% [markdown]
# ### Insights 4:
# Average dog ratings for each breed... (most likeable dog breed)

# %%
average_rating = twitter_archive_master.groupby("predicted_breed")['rating_numerator']

# %%
average_rating.mean().sort_values(ascending=False).head()
# Out:
# predicted_breed
# clumber                        27.000000
# soft-coated_wheaten_terrier    21.357143
# West_Highland_white_terrier    14.687500
# Great_Pyrenees                 14.666667
# chow                           14.166667
# Name: rating_numerator, dtype: float64

# %% [markdown]
# The results of the above code blocks show that the clumber breed has the highest average rating, with  soft coated wheaten terrier, west highland white terrier, great pyrenees and chow dogs with the next highest average ratings.

# %% [markdown]
# ### Visualization

# %%
sns.barplot(y="predicted_breed", x="Count", data=breed_count.head(10))
plt.title("Most Common Dog Breeds");

# %%
sns.barplot(y="predicted_breed", x="favorite_count", data=favorite_interactions_per_breed.head(10))
plt.title("Total Favourite Counts");

# %%
sns.barplot(y="predicted_breed", x="retweet_count", data=retweet_interactions_per_breed.head(10))
plt.title("Total Retweet Counts");

# %% [markdown]
# #### References
#
# 1. https://stackoverflow.com/
# 2. https://pandas.pydata.org/
# 3. https://classroom.udacity.com/me
